# %%
import pandas as pd

# %%
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")

# %%
train.head()
# Out:
#              ID  Customer_Birthyear Customer_Gender  \
# 0  TRAIN_000000                1980            male
# 1  TRAIN_000001                1964            male
# 2  TRAIN_000002                1982          female
# 3  TRAIN_000003                1982          female
# 4  TRAIN_000004                1982          female
#
#   Customer_personal_identifier Customer_identification_number  \
# 0                          이상호                 BJWQxd-WBASPLJ
# 1                          박상철                 kurCwX-odPUXEt
# 2                          조옥자                 OiERQa-CTXBoaX
# 3                          조옥자                 OiERQa-CTXBoaX
# 4                          조옥자                 OiERQa-CTXBoaX
#
#   Customer_registration_datetime Customer_credit_rating  \
# 0            2003-01-06 18:38:01                      B
# 1            2003-01-07 16:40:44                      C
# 2            2003-01-11 14:08:36                      B
# ...

# %%
for col in train.columns:
    print(f"## {col}")
    print("     unique length : ", len(train[col].unique()))
# Out:
# ## ID
#      unique length :  120000
# ## Customer_Birthyear
#      unique length :  55
# ## Customer_Gender
#      unique length :  2
# ## Customer_personal_identifier
#      unique length :  1769
# ## Customer_identification_number
#      unique length :  4101
# ## Customer_registration_datetime
#      unique length :  4101
# ## Customer_credit_rating
#      unique length :  6
# ## Customer_flag_change_of_authentication_1
#      unique length :  2
# ## Customer_flag_change_of_authentication_2
#      unique length :  2
# ## Customer_flag_change_of_authentication_3
#      unique length :  2
# ## Customer_flag_change_of_authentication_4
#      unique length :  2
# ## Customer_rooting_jailbreak_indicator
#      unique length :  2
# ## Customer_mobile_roaming_indicator
#      unique length :  2
# ## Customer_VPN_Indicator
#      unique length :  2
# ## Customer_loan_type
#      unique length :  5
# ## Customer_flag_terminal_malicious_behavior_1
#      unique length :  2
# ...

# %%
len(train["ID"].unique())
# Out:
# 120000

# %%
len(train["Customer_personal_identifier"].unique())
# Out:
# 1769

# %%
len(train["Customer_identification_number"].unique())
# Out:
# 4101

# %%
len(train["Customer_registration_datetime"].unique())
# Out:
# 4101
